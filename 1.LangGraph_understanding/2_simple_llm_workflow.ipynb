# %%
from langgraph.graph import StateGraph, START, END
from langchain_groq import ChatGroq
from typing import TypedDict
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
model = ChatGroq(model="llama-3.1-8b-instant")

# %% [markdown]
# Create a State

# %%
class LLMState(TypedDict):
    question: str
    answer: str

# %% [markdown]
# Create our Graph

# %%
graph = StateGraph(LLMState)

# %% [markdown]
# Add Nodes

# %%
def llm_qa(state: LLMState) -> LLMState:
    question = state['question']
    prompt = f"Answer the following question {question}"
    answer = model.invoke(prompt).content
    state['answer'] = answer
    return state

# %%
graph.add_node("llm_qa", llm_qa)

# %%
graph.add_edge(START, "llm_qa")
graph.add_edge("llm_qa", END)

# %%
workflow = graph.compile()

# %%
initial_state = {"question": "How far is moon from the earth?"}
final_state = workflow.invoke(initial_state)
print(final_state)
# Out:
# {'question': 'How far is moon from the earth?', 'answer': 'The average distance from the Earth to the Moon is approximately 384,400 kilometers (238,900 miles). This distance is also known as the "lunar distance" or "lunar mean distance." However, it\'s worth noting that the Moon\'s orbit is not a perfect circle and its distance from Earth varies slightly over the course of a month due to the elliptical shape of its orbit.\n\nAt its closest point, called "perigee," the Moon is about 363,104 kilometers (225,300 miles) away from Earth.\n\nAt its farthest point, called "apogee," the Moon is about 405,500 kilometers (252,000 miles) away from Earth.\n\nSo, the average distance is a good estimate, but the actual distance can vary by about 42,000 kilometers (26,100 miles) throughout the month.'}
