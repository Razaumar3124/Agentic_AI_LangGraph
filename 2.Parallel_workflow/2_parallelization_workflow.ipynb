# %%
from langgraph.graph import StateGraph, START, END
# from langchain_groq import ChatGroq
from langchain_google_genai import ChatGoogleGenerativeAI
from dotenv import load_dotenv
from typing import TypedDict, Annotated
from pydantic import BaseModel, Field
import operator

load_dotenv()
# Out:
# True

# %%
# model = ChatGroq(model="llama-3.1-8b-instant")
model = ChatGoogleGenerativeAI(model="gemini-2.5-flash")

# %% [markdown]
# Creating Schema using Pydantic

# %%
class EvaluateSchema(BaseModel):
    feedback: str = Field(description="Detailed feedback for the essay")
    score: int = Field(description="The final evaluation score as a single integer number between 0 and 10. DO NOT include any text, conversation, explanations, or quotes. Output ONLY the number.", ge=0, le=10)

# %% [markdown]
# Telling LLM to give Strucutred output in return

# %%
structured_model = model.with_structured_output(EvaluateSchema)

# %%
essay = """
The Transformative Role of Artificial Intelligence in India: Building a Viksit Bharat by 2047
Introduction
In November 2025, India stands at the cusp of an AI-driven renaissance. With a young population of 1.4 billion, the world's largest digital public infrastructure (DPI), and a government allocating over ₹10,300 crore through the IndiaAI Mission, artificial intelligence is no longer a futuristic dream—it is the engine powering inclusive growth. Prime Minister Narendra Modi’s vision of “AI for All” has evolved into concrete action: 34,000+ GPUs democratised for startups, indigenous multilingual LLMs like Kruti and BharatGen, and Centres of Excellence sprouting in Bengaluru, Maharashtra, and Andhra Pradesh. AI is projected to add $500 billion to India’s GDP by the end of this year alone, lifting millions out of poverty while positioning the nation as the world’s third-largest AI market.
AI in Agriculture: From Subsistence to Precision Farming
India feeds 18% of the world’s population with just 2.4% of its land. AI is rewriting that equation.

Disease detection at 95% accuracy: Neural networks now spot apple scab and wheat rust faster than human eyes, slashing crop losses by 20–30%.
Drone swarms over Punjab: 100 free AI-guided drones distributed in 2025 spray pesticides only where needed, saving water and boosting yields by 15%.
Satellite + GenAI advisories: Maharashtra’s Google-partnered CoE delivers hyper-local weather and soil-health alerts in 22 languages to 50 million farmers via WhatsApp.

The Future Farming Playbook, due early 2026, will scale these pilots nationwide, turning every smartphone into a farm consultant.
AI in Healthcare: A Doctor in Every Pocket
India’s doctor-to-patient ratio hovers at 1:900. AI is bridging the gap.

Niramai’s thermal AI: Detects breast cancer five years earlier than mammograms, now screening 1.2 million rural women free via Ayushman Bharat.
Qure.ai’s chest X-ray bots: Read 10,000 scans daily in PHCs, catching TB 11% faster than radiologists.
Predictive OPD queues: Andhra’s Gates Foundation pilot uses AI to cut wait times by 40%, freeing doctors for complex cases.

By 2030, AI-driven diagnostics will save ₹1.2 lakh crore in out-of-pocket expenses and add 8–10 years to average rural life expectancy.
AI in Education: Personal Tutors for 250 Million Students
Seventy-two percent of Indian professionals already learn AI on their own; the government is catching up.

₹500-crore CoE for AI in Education: Launched in Budget 2025, it powers adaptive platforms that teach maths in Tamil, science in Bengali, and coding in Hindi.
BHASHINI’s 1,600+ models: Translate NCERT textbooks in real time; 35 million students used AI voice tutors in 2025.
Skill India 2.0: Five National Centres of Excellence will certify 1 million AI trainers by 2027, turning Tier-2 colleges into talent factories.

Dropout rates in government schools have fallen 18% where AI chatbots provide 24×7 doubt clearance.
Governance & Industry: The Invisible Hand of AI

Aadhaar + AI fraud detection: Prevented ₹2,300 crore in ghost pensions in 2025 alone.
Gati Shakti on steroids: Predictive logistics shaved 12% off freight costs for Indian Railways.
Startup explosion: 150+ GenAI unicorns-to-be raised $61 million in the last cohort of Google’s AI First accelerator. Sarvam, Krutrim, and Soket now power sovereign LLMs in 22 scheduled languages.

The Talent Challenge: One Engineer for Every Ten Jobs
Demand for AI professionals will hit 2.3 million by 2027; supply may reach only 1.2 million. Freshers with GitHub portfolios earn 4× the average campus salary.
Fixes already rolling out:

50,000 GPUs at ₹2.5/lakh per month for students.
Reverse brain-drain visas for 10,000 returning PhDs.
Mandatory AI modules in every B.Tech syllabus from 2026.

Conclusion: AI as India’s Next Freedom Struggle
In 1947, India won political freedom. In 2025, AI is delivering economic freedom—one predictive harvest, one early cancer scan, one personalised lesson at a time. The IndiaAI Mission is not just building models; it is building hope. By 2030, an AI-literate Bharat will not follow Silicon Valley—it will lead it, proving that technology, when rooted in inclusivity, can turn 1.4 billion dreams into reality.
As Union Minister Ashwini Vaishnaw says, “AI is not a job killer; it is a job multiplier—for those ready to learn.” India is ready. The algorithm is ours. Jai Hind. 🇮🇳
"""

# %%
essay2 = """
The Role of AI in India
Intoducton
Artificail Intellegence (AI) is changin the hole world super fastly, and India is no exepton at all ever. With its enormus populaton and rapid growin tech industy, India are adoptin AI in countles many many sectors everywher. This essay will discus in detial how AI is playin a absolutly importent role in India's economi, helthcare, agricultre, educaton, transport and even lot more. But there is also tonns of chalenges that need to be adressed urgntly right now.
AI in Economi and Jobbs
India's economi is absolutly boomin with AI technolgy every day. Big big companys like Infosys, TCS and thosands of startups in Banglore are usin AI for data analisis and automatin everythin possible. Goverment initatives like Digital India and Make in India is strongli promotin AI to create bilions of jobs for everybodys. But many many peoples worry alot that AI will take away all jobs from workers in call centres and manufacturin plants completly. Insted of fearin so much, India should train its youth in AI skillz through programms like Skill India wich is extremly good and helpfull.
AI is helpin in finacial servises way too much. Banks use AI for fraud detectin and chatbots for custmer service wich is totaly amazin and fast. Paytm and PhonePe apps rely heavly on AI for smooth transctions and instant payments. This make whole economi more efficent but also raise hundrds of issues of data privasy, securty and hackin.
Helthcare Revolutons
In helthcare, AI is a total game changer for India where docters are very less in rural areas and small villges. AI tools like those from Apollo Hospitles use machine learnin to diagnos all diseases from X-rays and MRI scans super quicky. During COVID-19 pandamic, AI helped alot in trackin millions cases and predictin spreads all over the country everywher.
Startups are developin AI for telemedicin, allowin patients in remote villges to consult docters online without any travelin at all. This reduce travel costs massivly and save countles lives everyday. However, not every single one has access to internet or smartphon, so goverment need to improve infrastucture super fastly and urgent.
Agricultre and Farminn
India is a pure agricultarl country with bilions of farmrs workin extremly hard. AI is transformin farmin with drone technolgy and predictive analitics tools everywher. Companys like Microsoft partner with thosands farmrs to use AI for soil helth, weather forcastin and crop yeild predictin accuratly. This help reduce water usag drasticaly and increase productin massivly.
Apps like Kisan Network use AI to connect farmrs directly to buyers, cuttin all middlemen completly forever. But small poor farmrs cant afford these expensiv tools at all, so subsidys are needed from goverment immediatly without delay.
Educaton and Learninn
In educaton, AI is personalizin learnin for every singl student individully. Platforms like Byju's use AI to adapt lessons to student needs and levels instanty. This is extremly usefull in a country with divers hundrds languages and learnin paces varyin alot. AI chatbots help students with homewrk and doubt clearin 24/7 non stop.
During pandemics, online educaton boomed with AI supportin everythin. But digital divid means many poor students miss out completly totaly. Teachers also need intensiv trainin to use AI effectivly in classroms every day.
More Sectors: Smart Citys and Transprt
AI is also enterin smart citys project everywher. In places like Delhi and Mumbai, AI manage traffic lights, reduce congesion massivly and predict accidents before they happen. Self-drivin cars are bein tested but road conditons are terible so very chalengin.
In transprt, apps like Ola and Uber use AI for route optimizatin and price surgin dynamicly. This make travel easyer and faster but drivers complain alot about low earnins and no money.
Even More: Goverment and Defens
AI is helpin goverment in e-goverance, predictin crimes and managin public servises. Police use AI for facial recognitin but privasy issues rise. In defens, DRDO develop AI drones and missils for securty.
Chalenges and Futurr
Despite all these benefits, AI in India face countles many problems every day. There is complet lack of data protecton laws, leadin to massiv misus of personal infomation by big companys. Ethical issues like bias in AI algoritms can discriminat against certain groups, cast and communties badly. India need strong urgent regulatons like the proposd Personal Data Protecton Bill as soon as possibl.
Also, power consumtin of AI data centres is extremly high, and India strugles with energy shortags every singl day. Investin in green AI is absolutly importent for environmnt and planet.
In futurr, India aim to be a global AI superpowr soon. With initatives like National AI Stratgy, it can lead in world AI reserch and developmnt totaly. But inclusivity is absolut key so that AI benefit all Indians everywher, not just urban elit and super rich peoples only.
Conclutionn
AI is playin a absolut vital role in India's developmnt across all various fieldz and sectors. It bring countles oppurtunities for growth but also requir extrem careful handlin of all riskz and dangers. By investin heavly in educaton, infrastucture and policys, India can harnes AI for a much better tomorow for everybodys. The journy has just began and will continyu forever and ever.
"""

# %%
prompt = f"""Evaluate the language quality of the following essay and provide a feedback and assign a score out of 10 \n {essay}"""
structured_model.invoke(prompt)
# Out:
# EvaluateSchema(feedback="The essay demonstrates excellent language quality. The vocabulary is rich and precise, effectively conveying complex ideas related to AI's impact on various sectors in India. Sentence structures are varied and sophisticated, maintaining a professional and engaging tone throughout. The essay is well-organized, with clear topic sentences and smooth transitions between paragraphs, enhancing readability and logical flow. There are no significant grammatical errors or punctuation mistakes, indicating a high level of linguistic proficiency. The use of specific data, examples, and future projections adds credibility and depth to the arguments. The conclusion effectively summarizes the main points and leaves a strong impression. Overall, the language is compelling, articulate, and highly persuasive.", score=9)

# %%
class UPSCState(TypedDict):
    essay: str
    language_feedback: str
    analysis_feedback: str
    clarity_feedback: str
    overall_feedback: str
    individual_scores: Annotated[list[int], operator.add]
    avg_score: float

# %%
graph = StateGraph(UPSCState)

# %% [markdown]
# Node Functions

# %%
def evaluate_language(state: UPSCState):
    
    prompt = f"Evaluate the language quality of the following essay and provide a feedback and assign a score out of 10 \n {state['essay']}"
    
    output = structured_model.invoke(prompt)
    
    return {"language_feedback": output.feedback, "individual_scores": [output.score]}

# %%
def evaluate_analysis(state: UPSCState):
    
    prompt = f"Evaluate the depth of analysis of the following essay and provide a feedback and assign a score out of 10 \n {state['essay']}"
    
    output = structured_model.invoke(prompt)
    
    return {"analysis_feedback": output.feedback, "individual_scores": [output.score]}

# %%
def evaluate_thought(state: UPSCState):
    
    prompt = f"Evaluate the clarity of thought of the following essay and provide a feedback and assign a score out of 10 \n {state['essay']}"
    
    output = structured_model.invoke(prompt)
    
    return {"clarity_feedback": output.feedback, "individual_scores": [output.score]}

# %%
def final_evaluation(state: UPSCState):
    prompt = f"Based on the following feedbacks create a summarized feedback \n language feedback - {state['language_feedback']} \n  depth of analysis feedback - {state['analysis_feedback']} \n clarity of the thought feedback - {state['clarity_feedback']}"
    
    overall_feedback = model.invoke(prompt).content
    
    avg_score = sum(state['individual_scores']) / len(state['individual_scores'])
    
    return {"overall_feedback": overall_feedback, "avg_score": avg_score}

# %% [markdown]
# Add Nodes

# %%
graph.add_node("evaluate_language", evaluate_language)
graph.add_node("evaluate_analysis", evaluate_analysis)
graph.add_node("evaluate_thought", evaluate_thought)
graph.add_node("final_evaluation", final_evaluation)

# %% [markdown]
# Add Edges

# %%
graph.add_edge(START, "evaluate_language")
graph.add_edge(START, "evaluate_analysis")
graph.add_edge(START, "evaluate_thought")

graph.add_edge("evaluate_language", "final_evaluation")
graph.add_edge("evaluate_analysis", "final_evaluation")
graph.add_edge("evaluate_thought", "final_evaluation")

graph.add_edge("final_evaluation", END)

# %%
workflow = graph.compile()

# %%
initial_state = {
    "essay": essay
}

workflow.invoke(initial_state)
# Out:
# {'essay': "\nThe Transformative Role of Artificial Intelligence in India: Building a Viksit Bharat by 2047\nIntroduction\nIn November 2025, India stands at the cusp of an AI-driven renaissance. With a young population of 1.4 billion, the world's largest digital public infrastructure (DPI), and a government allocating over ₹10,300 crore through the IndiaAI Mission, artificial intelligence is no longer a futuristic dream—it is the engine powering inclusive growth. Prime Minister Narendra Modi’s vision of “AI for All” has evolved into concrete action: 34,000+ GPUs democratised for startups, indigenous multilingual LLMs like Kruti and BharatGen, and Centres of Excellence sprouting in Bengaluru, Maharashtra, and Andhra Pradesh. AI is projected to add $500 billion to India’s GDP by the end of this year alone, lifting millions out of poverty while positioning the nation as the world’s third-largest AI market.\nAI in Agriculture: From Subsistence to Precision Farming\nIndia feeds 18% of the 
# ...
