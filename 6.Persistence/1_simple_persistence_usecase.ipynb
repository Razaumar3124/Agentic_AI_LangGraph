# %%
from langgraph.graph import StateGraph, START, END
from langgraph.checkpoint.memory import InMemorySaver
from langchain_groq import ChatGroq
from typing import TypedDict
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
model = ChatGroq(model="llama-3.1-8b-instant")

# %%
class JokeState(TypedDict):
    topic: str
    joke: str
    explanation: str

# %%
graph = StateGraph(JokeState)

# %%
def generate_joke(state: JokeState):
    prompt = f"generate a joke on the topic {state['topic']}"
    joke = model.invoke(prompt).content
    return {"joke": joke}

# %%
def generate_explanation(state: JokeState):
    prompt = f"Write an explanation for the joke :- \n {state['joke']}"
    explanation = model.invoke(prompt).content
    return {"explanation": explanation}

# %%
graph.add_node("generate_joke", generate_joke)
graph.add_node("generate_explanation", generate_explanation)

# %%
graph.add_edge(START, "generate_joke")
graph.add_edge("generate_joke", "generate_explanation")
graph.add_edge("generate_explanation", END)

# %%
checkpointer = InMemorySaver()

# %%
workflow = graph.compile(checkpointer=checkpointer)

# %%
config1 = {"configurable": {"thread_id": 1}}
workflow.invoke({"topic": "pizza"}, config=config1)
# Out:
# {'topic': 'pizza',
#  'joke': 'Why was the pizza in a bad mood? \n\nIt was feeling a little crusty.',
#  'explanation': 'This is a play on words, which is a common technique used in humor. The joke relies on a dual meaning of the word "crusty."\n\nIn the context of a pizza, "crusty" refers to the crispy outer layer of the bread. This is a literal meaning of the word.\n\nHowever, the phrase "feeling a little crusty" is also an idiomatic expression that means being in a bad mood or irritable. This is a figurative meaning of the word.\n\nThe joke is funny because it takes the literal meaning of "crusty" (the pizza\'s outer layer) and applies it to the idiomatic meaning (being in a bad mood). It\'s a clever play on words that creates a pun, which is a type of humor that relies on multiple meanings of a word or phrase.\n\nIn essence, the joke is saying that the pizza is feeling bad (bad mood) because it\'s got a "crusty" exterior (the pizza itself). The humor comes from the unexpected twist on the usual meaning of the word "crusty."'}

# %%
workflow.get_state(config1)
# Out:
# StateSnapshot(values={'topic': 'pizza', 'joke': 'Why was the pizza in a bad mood? \n\nIt was feeling a little crusty.', 'explanation': 'This is a play on words, which is a common technique used in humor. The joke relies on a dual meaning of the word "crusty."\n\nIn the context of a pizza, "crusty" refers to the crispy outer layer of the bread. This is a literal meaning of the word.\n\nHowever, the phrase "feeling a little crusty" is also an idiomatic expression that means being in a bad mood or irritable. This is a figurative meaning of the word.\n\nThe joke is funny because it takes the literal meaning of "crusty" (the pizza\'s outer layer) and applies it to the idiomatic meaning (being in a bad mood). It\'s a clever play on words that creates a pun, which is a type of humor that relies on multiple meanings of a word or phrase.\n\nIn essence, the joke is saying that the pizza is feeling bad (bad mood) because it\'s got a "crusty" exterior (the pizza itself). The humor comes from the unexpected twist on the usual meaning of the word "crusty."'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0bbca9-f969-60ae-800e-1ad9e595d71d'}}, metadata={'source': 'loop', 'step': 14, 'parents': {}}, created_at='2025-11-07T11:12:18.371790+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0bbca9-f5f8-6614-800d-141cb281e62a'}}, tasks=(), interrupts=())

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'pizza', 'joke': 'Why was the pizza in a bad mood? \n\nIt was feeling a little crusty.', 'explanation': 'This is a play on words, which is a common technique used in humor. The joke relies on a dual meaning of the word "crusty."\n\nIn the context of a pizza, "crusty" refers to the crispy outer layer of the bread. This is a literal meaning of the word.\n\nHowever, the phrase "feeling a little crusty" is also an idiomatic expression that means being in a bad mood or irritable. This is a figurative meaning of the word.\n\nThe joke is funny because it takes the literal meaning of "crusty" (the pizza\'s outer layer) and applies it to the idiomatic meaning (being in a bad mood). It\'s a clever play on words that creates a pun, which is a type of humor that relies on multiple meanings of a word or phrase.\n\nIn essence, the joke is saying that the pizza is feeling bad (bad mood) because it\'s got a "crusty" exterior (the pizza itself). The humor comes from the unexpected twist on the usual meaning of the word "crusty."'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0bbca9-f969-60ae-800e-1ad9e595d71d'}}, metadata={'source': 'loop', 'step': 14, 'parents': {}}, created_at='2025-11-07T11:12:18.371790+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0bbca9-f5f8-6614-800d-141cb281e62a'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why was the pizza in a bad mood? \n\nIt was feeling a little crusty.', 'explanation': 'This joke is an example of a play on words, which is a type of wordplay that uses multiple meanings of a word or phrase to create a pun. In this case, the word "crusty" has two different meanings.\n\nOn one hand, "crusty" can describe something that is rough or hardened on the outside, like a crust on a pizza. This is the literal meaning of the word.\n\nOn the other hand, "crusty" can also describe someone or something that is irritable or in a bad mood. This is a more figurative or idiomatic meaning of the word.\n\nThe joke works by exploiting this double meaning of "crusty". When someone asks why the pizza is in a bad mood, the punchline "it was feeling a little crusty" uses the literal meaning of "crusty" to make a pun on the fact that pizza has a crust. At the same time, it also uses the idiomatic meaning of "crusty" to describe the pizza\'s bad mood.\n\nThe humor in the joke comes from the unexpected twist on the word "crusty" and the clever way it\'s used to make a connection between the pizza\'s physical characteristics and its emotional state.'}, next=('generate_explanation',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0bbca9-f5f8-6614-800d-141cb281e62a'}}, metadata={'source': 'loop', 'step': 13, 'parents': {}}, created_at='2025-11-07T11:12:18.011069+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0bbca9-f49c-65d0-800c-def9bf455bcc'}}, tasks=(PregelTask(id='f2dc0b84-3673-d106-b9e1-9fe5d1d63cf4', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'This is a play on words, which is a common technique used in humor. The joke relies on a dual meaning of the word "crusty."\n\nIn the context of a pizza, "crusty" refers to the crispy outer layer of the bread. This is a literal meaning of the word.\n\nHowever, the phrase "feeling a little crusty" is also an idiomatic expression that means being in a bad mood or irritable. This is a figurative meaning of the word.\n\nThe joke is funny because it takes the literal meaning of "crusty" (the pizza\'s outer layer) and applies it to the idiomatic meaning (being in a bad mood). It\'s a clever play on words that creates a pun, which is a type of humor that relies on multiple meanings of a word or phrase.\n\nIn essence, the joke is saying that the pizza is feeling bad (bad mood) because it\'s got a "crusty" exterior (the pizza itself). The humor comes from the unexpected twist on the usual meaning of the word "crusty."'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why was the pizza in a bad mood? \n\nBecause it was feeling a little crusty.', 'explanation': 'This joke is an example of a play on words, which is a type of wordplay that uses multiple meanings of a word or phrase to create a pun. In this case, the word "crusty" has two different meanings.\n\nOn one hand, "crusty" can describe something that is rough or hardened on the outside, like a crust on a pizza. This is the literal meaning of the word.\n\nOn the other hand, "crusty" can also describe someone or something that is irritable or in a bad mood. This is a more figurative or idiomatic meaning of the word.\n\nThe joke works by exploiting this double meaning of "crusty". When someone asks why the pizza is in a bad mood, the punchline "it was feeling a little crusty" uses the literal meaning of "crusty" to make a pun on the fact that pizza has a crust. At the same time, it also uses the idiomatic meaning of "crusty" to describe the pizza\'s bad mood.\n\nThe humor in the joke comes from the unexpected twist on the word "crusty" and the clever way it\'s used to make a connection between the pizza\'s physical characteristics and its emotional state.'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0bbca9-f49c-65d0-800c-def9bf455bcc'}}, metadata={'source': 'loop', 'step': 12, 'parents': {}}, created_at='2025-11-07T11:12:17.868517+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0bbca9-f486-6683-800b-6ec3b7abb94a'}}, tasks=(PregelTask(id='a8ea995d-8806-e4f2-a999-287b2ab43c76', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why was the pizza in a bad mood? \n\nIt was feeling a little crusty.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why was the pizza in a bad mood? \n\nBecause it was feeling a little crusty.', 'explanation': 'This joke is an example of a play on words, which is a type of wordplay that uses multiple meanings of a word or phrase to create a pun. In this case, the word "crusty" has two different meanings.\n\nOn one hand, "crusty" can describe something that is rough or hardened on the outside, like a crust on a pizza. This is the literal meaning of the word.\n\nOn the other hand, "crusty" can also describe someone or something that is irritable or in a bad mood. This is a more figurative or idiomatic meaning of the word.\n\nThe joke works by exploiting this double meaning of "crusty". When someone asks why the pizza is in a bad mood, the punchline "it was feeling a little crusty" uses the literal meaning of "crusty" to make a pun on the fact that pizza has a crust. At the same time, it also uses the idiomatic meaning of "crusty" to describe the pizza\'s bad mood.\n\nThe humor in the joke comes from the unexpected twist on the word "crusty" and the clever way it\'s used to make a connection between the pizza\'s physical characteristics and its emotional state.'}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0bbca9-f486-6683-800b-6ec3b7abb94a'}}, metadata={'source': 'input', 'step': 11, 'parents': {}}, created_at='2025-11-07T11:12:17.859525+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0bbca0-31b4-6fc3-800a-864e905677f5'}}, tasks=(PregelTask(id='e5cf3b81-1248-7ebb-e359-430e477b10ec', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'pizza'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why was the pizza in a bad mood? \n\nBecause it was feeling a little crusty.', 'explanation': 'This joke is an example of a play on words, which is a type of wordplay that uses multiple meanings of a word or phrase to create a pun. In this case, the word "crusty" has two different meanings.\n\nOn one hand, "crusty" can describe something that is rough or hardened on the outside, like a crust on a pizza. This is the literal meaning of the word.\n\nOn the other hand, "crusty" can also describe someone or something that is irritable or in a bad mood. This is a more figurative or idiomatic meaning of the word.\n\nThe joke works by exploiting this double meaning of "crusty". When someone asks why the pizza is in a bad mood, the punchline "it was feeling a little crusty" uses the literal meaning of "crusty" to make a pun on the fact that pizza has a crust. At the same time, it also uses the idiomatic meaning of "crusty" to describe the pizza\'s bad mood.\n\nThe humor in the joke comes from the unexpected twist on the word "crusty" and the clever way it\'s used to make a connection between the pizza\'s physical characteristics and its emotional state.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0bbca0-31b4-6fc3-800a-864e905677f5'}}, metadata={'source': 'loop', 'step': 10, 'parents': {}}, created_at='2025-11-07T11:07:55.839450+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0bbca0-2d9e-6a85-8009-18dcc9d68667'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why was the pizza in a bad mood? \n\nBecause it was feeling a little crusty.', 'explanation': 'The joke is a play on words. It\'s a pun that uses the double meaning of the word "crusty" to create a humorous effect.\n\nIn this context, the word "crusty" has a literal meaning, referring to the crust of a pizza. However, it also has a figurative meaning, describing someone or something as being a little rough or irritable around the edges, often due to being stressed or unwell.\n\nThe punchline "it was feeling a little crusty" is a clever play on these two meanings. The speaker is making a joke about the pizza going to the doctor because it\'s feeling unwell, but also referencing the literal crust of the pizza. The humor comes from the unexpected twist on the usual meaning of the word, creating a clever and amusing connection between the setup and the punchline.'}, next=('generate_explanation',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0bbca0-2d9e-6a85-8009-18dcc9d68667'}}, metadata={'source': 'loop', 'step': 9, 'parents': {}}, created_at='2025-11-07T11:07:55.410879+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0bbca0-2c01-680d-8008-816aedf828a2'}}, tasks=(PregelTask(id='95040aea-0fa9-f76b-f7f5-33d4d8804967', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'This joke is an example of a play on words, which is a type of wordplay that uses multiple meanings of a word or phrase to create a pun. In this case, the word "crusty" has two different meanings.\n\nOn one hand, "crusty" can describe something that is rough or hardened on the outside, like a crust on a pizza. This is the literal meaning of the word.\n\nOn the other hand, "crusty" can also describe someone or something that is irritable or in a bad mood. This is a more figurative or idiomatic meaning of the word.\n\nThe joke works by exploiting this double meaning of "crusty". When someone asks why the pizza is in a bad mood, the punchline "it was feeling a little crusty" uses the literal meaning of "crusty" to make a pun on the fact that pizza has a crust. At the same time, it also uses the idiomatic meaning of "crusty" to describe the pizza\'s bad mood.\n\nThe humor in the joke comes from the unexpected twist on the word "crusty" and the clever way it\'s used to make a connection between the pizza\'s physical characteristics and its emotional state.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza go to the doctor? \n\nBecause it was feeling a little crusty.', 'explanation': 'The joke is a play on words. It\'s a pun that uses the double meaning of the word "crusty" to create a humorous effect.\n\nIn this context, the word "crusty" has a literal meaning, referring to the crust of a pizza. However, it also has a figurative meaning, describing someone or something as being a little rough or irritable around the edges, often due to being stressed or unwell.\n\nThe punchline "it was feeling a little crusty" is a clever play on these two meanings. The speaker is making a joke about the pizza going to the doctor because it\'s feeling unwell, but also referencing the literal crust of the pizza. The humor comes from the unexpected twist on the usual meaning of the word, creating a clever and amusing connection between the setup and the punchline.'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0bbca0-2c01-680d-8008-816aedf828a2'}}, metadata={'source': 'loop', 'step': 8, 'parents': {}}, created_at='2025-11-07T11:07:55.241661+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0bbca0-2bff-6105-8007-63cbcd8a405f'}}, tasks=(PregelTask(id='7d80a38c-7fad-2295-2050-9c6894f7f4b1', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why was the pizza in a bad mood? \n\nBecause it was feeling a little crusty.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza go to the doctor? \n\nBecause it was feeling a little crusty.', 'explanation': 'The joke is a play on words. It\'s a pun that uses the double meaning of the word "crusty" to create a humorous effect.\n\nIn this context, the word "crusty" has a literal meaning, referring to the crust of a pizza. However, it also has a figurative meaning, describing someone or something as being a little rough or irritable around the edges, often due to being stressed or unwell.\n\nThe punchline "it was feeling a little crusty" is a clever play on these two meanings. The speaker is making a joke about the pizza going to the doctor because it\'s feeling unwell, but also referencing the literal crust of the pizza. The humor comes from the unexpected twist on the usual meaning of the word, creating a clever and amusing connection between the setup and the punchline.'}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0bbca0-2bff-6105-8007-63cbcd8a405f'}}, metadata={'source': 'input', 'step': 7, 'parents': {}}, created_at='2025-11-07T11:07:55.240659+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0bbc9f-db0d-6b21-8006-41adbb021c4b'}}, tasks=(PregelTask(id='f017f659-4c1a-320d-3b0f-c0692cb1e746', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'pizza'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza go to the doctor? \n\nBecause it was feeling a little crusty.', 'explanation': 'The joke is a play on words. It\'s a pun that uses the double meaning of the word "crusty" to create a humorous effect.\n\nIn this context, the word "crusty" has a literal meaning, referring to the crust of a pizza. However, it also has a figurative meaning, describing someone or something as being a little rough or irritable around the edges, often due to being stressed or unwell.\n\nThe punchline "it was feeling a little crusty" is a clever play on these two meanings. The speaker is making a joke about the pizza going to the doctor because it\'s feeling unwell, but also referencing the literal crust of the pizza. The humor comes from the unexpected twist on the usual meaning of the word, creating a clever and amusing connection between the setup and the punchline.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0bbc9f-db0d-6b21-8006-41adbb021c4b'}}, metadata={'source': 'loop', 'step': 6, 'parents': {}}, created_at='2025-11-07T11:07:46.753177+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0bbc9f-d7ca-6bb2-8005-567d4f808fc8'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza go to the doctor? \n\nBecause it was feeling a little crusty.', 'explanation': 'The joke is a play on words, using a pun to create humor. \n\nIn this joke, the phrase "feeling a little crusty" has a double meaning. \n\n1. In everyday language, "crusty" can describe something that is a bit rough or gruff, often used to describe a person\'s mood. \n2. In the context of food, "crusty" specifically refers to the crust of a pizza, which is a characteristic texture of the dish.\n\nThe joke relies on this dual meaning to create a pun. By saying that the pizza "was feeling a little crusty," the speaker is making a joke about the pizza\'s emotional state (feeling a bit rough) while also referencing the pizza\'s physical characteristic (its crust).\n\nThis type of wordplay is a common technique used in humor, and it\'s the key to understanding and enjoying the joke.'}, next=('generate_explanation',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0bbc9f-d7ca-6bb2-8005-567d4f808fc8'}}, metadata={'source': 'loop', 'step': 5, 'parents': {}}, created_at='2025-11-07T11:07:46.411192+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0bbc9f-d65e-6487-8004-cccc9e930872'}}, tasks=(PregelTask(id='1da012b3-30b7-cff8-1183-e5cbcfbd18b0', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'The joke is a play on words. It\'s a pun that uses the double meaning of the word "crusty" to create a humorous effect.\n\nIn this context, the word "crusty" has a literal meaning, referring to the crust of a pizza. However, it also has a figurative meaning, describing someone or something as being a little rough or irritable around the edges, often due to being stressed or unwell.\n\nThe punchline "it was feeling a little crusty" is a clever play on these two meanings. The speaker is making a joke about the pizza going to the doctor because it\'s feeling unwell, but also referencing the literal crust of the pizza. The humor comes from the unexpected twist on the usual meaning of the word, creating a clever and amusing connection between the setup and the punchline.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza go to the doctor? \n\nBecause it was feeling a little crusty.', 'explanation': 'The joke is a play on words, using a pun to create humor. \n\nIn this joke, the phrase "feeling a little crusty" has a double meaning. \n\n1. In everyday language, "crusty" can describe something that is a bit rough or gruff, often used to describe a person\'s mood. \n2. In the context of food, "crusty" specifically refers to the crust of a pizza, which is a characteristic texture of the dish.\n\nThe joke relies on this dual meaning to create a pun. By saying that the pizza "was feeling a little crusty," the speaker is making a joke about the pizza\'s emotional state (feeling a bit rough) while also referencing the pizza\'s physical characteristic (its crust).\n\nThis type of wordplay is a common technique used in humor, and it\'s the key to understanding and enjoying the joke.'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0bbc9f-d65e-6487-8004-cccc9e930872'}}, metadata={'source': 'loop', 'step': 4, 'parents': {}}, created_at='2025-11-07T11:07:46.261905+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0bbc9f-d659-69fb-8003-77a2fd293ae3'}}, tasks=(PregelTask(id='a89bd7eb-ceb8-5799-998b-bf1dcae2dbb5', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why did the pizza go to the doctor? \n\nBecause it was feeling a little crusty.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza go to the doctor? \n\nBecause it was feeling a little crusty.', 'explanation': 'The joke is a play on words, using a pun to create humor. \n\nIn this joke, the phrase "feeling a little crusty" has a double meaning. \n\n1. In everyday language, "crusty" can describe something that is a bit rough or gruff, often used to describe a person\'s mood. \n2. In the context of food, "crusty" specifically refers to the crust of a pizza, which is a characteristic texture of the dish.\n\nThe joke relies on this dual meaning to create a pun. By saying that the pizza "was feeling a little crusty," the speaker is making a joke about the pizza\'s emotional state (feeling a bit rough) while also referencing the pizza\'s physical characteristic (its crust).\n\nThis type of wordplay is a common technique used in humor, and it\'s the key to understanding and enjoying the joke.'}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0bbc9f-d659-69fb-8003-77a2fd293ae3'}}, metadata={'source': 'input', 'step': 3, 'parents': {}}, created_at='2025-11-07T11:07:46.259995+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0bbc9e-0661-6bdd-8002-75142b06c86b'}}, tasks=(PregelTask(id='1fb5099d-1e19-5cd3-c8fd-5dcd750d4670', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'pizza'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza go to the doctor? \n\nBecause it was feeling a little crusty.', 'explanation': 'The joke is a play on words, using a pun to create humor. \n\nIn this joke, the phrase "feeling a little crusty" has a double meaning. \n\n1. In everyday language, "crusty" can describe something that is a bit rough or gruff, often used to describe a person\'s mood. \n2. In the context of food, "crusty" specifically refers to the crust of a pizza, which is a characteristic texture of the dish.\n\nThe joke relies on this dual meaning to create a pun. By saying that the pizza "was feeling a little crusty," the speaker is making a joke about the pizza\'s emotional state (feeling a bit rough) while also referencing the pizza\'s physical characteristic (its crust).\n\nThis type of wordplay is a common technique used in humor, and it\'s the key to understanding and enjoying the joke.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0bbc9e-0661-6bdd-8002-75142b06c86b'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2025-11-07T11:06:57.609382+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0bbc9e-02f2-6be1-8001-ef7600ca9f4c'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza go to the doctor? \n\nBecause it was feeling a little crusty.'}, next=('generate_explanation',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0bbc9e-02f2-6be1-8001-ef7600ca9f4c'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2025-11-07T11:06:57.249352+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0bbc9e-016e-6ff2-8000-a2ac49c02551'}}, tasks=(PregelTask(id='9bdfccf6-21ce-a7c5-18f3-4c2fe4f6af4e', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'The joke is a play on words, using a pun to create humor. \n\nIn this joke, the phrase "feeling a little crusty" has a double meaning. \n\n1. In everyday language, "crusty" can describe something that is a bit rough or gruff, often used to describe a person\'s mood. \n2. In the context of food, "crusty" specifically refers to the crust of a pizza, which is a characteristic texture of the dish.\n\nThe joke relies on this dual meaning to create a pun. By saying that the pizza "was feeling a little crusty," the speaker is making a joke about the pizza\'s emotional state (feeling a bit rough) while also referencing the pizza\'s physical characteristic (its crust).\n\nThis type of wordplay is a common technique used in humor, and it\'s the key to understanding and enjoying the joke.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0bbc9e-016e-6ff2-8000-a2ac49c02551'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2025-11-07T11:06:57.090539+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0bbc9e-0164-69d8-bfff-7a38033bdc68'}}, tasks=(PregelTask(id='9e859234-5eed-e777-a1b6-5977a68a5001', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why did the pizza go to the doctor? \n\nBecause it was feeling a little crusty.'}),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0bbc9e-0164-69d8-bfff-7a38033bdc68'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2025-11-07T11:06:57.086295+00:00', parent_config=None, tasks=(PregelTask(id='1cc2c2ac-a990-1ca1-157a-1f606bf78ead', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'pizza'}),), interrupts=())]

# %%
config2 = {"configurable": {"thread_id": 2}}
workflow.invoke({"topic": "pasta"}, config=config2)
# Out:
# {'topic': 'pasta',
#  'joke': 'Why did the spaghetti go to therapy? \n\nBecause it was feeling a little "twisted".',
#  'explanation': 'The joke is a play on words. It starts with a setup question, "Why did the spaghetti go to therapy?" which implies that the spaghetti has a problem or is feeling unhappy. The punchline, "Because it was feeling a little \'twisted\'" has a double meaning.\n\nIn a literal sense, spaghetti is a type of food that is long and twisted in shape. So, the punchline is making a joke about the physical appearance of spaghetti.\n\nHowever, the phrase "feeling a little twisted" is also an idiom that means feeling anxious, confused, or disturbed. In this sense, the punchline is making a joke about the emotional state of the spaghetti.\n\nThe humor comes from the wordplay between the literal meaning of "twisted" (referring to the spaghetti\'s shape) and the idiomatic meaning (referring to the emotional state of the spaghetti). The joke is a clever and lighthearted way to make a pun on the word "twisted" and create a humorous connection between the setup and the punchline.'}

# %%
workflow.get_state(config2)
# Out:
# StateSnapshot(values={'topic': 'pasta', 'joke': 'Why did the spaghetti go to therapy? \n\nBecause it was feeling a little "twisted".', 'explanation': 'The joke is a play on words. It starts with a setup question, "Why did the spaghetti go to therapy?" which implies that the spaghetti has a problem or is feeling unhappy. The punchline, "Because it was feeling a little \'twisted\'" has a double meaning.\n\nIn a literal sense, spaghetti is a type of food that is long and twisted in shape. So, the punchline is making a joke about the physical appearance of spaghetti.\n\nHowever, the phrase "feeling a little twisted" is also an idiom that means feeling anxious, confused, or disturbed. In this sense, the punchline is making a joke about the emotional state of the spaghetti.\n\nThe humor comes from the wordplay between the literal meaning of "twisted" (referring to the spaghetti\'s shape) and the idiomatic meaning (referring to the emotional state of the spaghetti). The joke is a clever and lighthearted way to make a pun on the word "twisted" and create a humorous connection between the setup and the punchline.'}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0bbcad-2048-637d-800a-235ac3512b20'}}, metadata={'source': 'loop', 'step': 10, 'parents': {}}, created_at='2025-11-07T11:13:42.978432+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0bbcad-1c6d-6f97-8009-1d81aacee34a'}}, tasks=(), interrupts=())

# %%
list(workflow.get_state_history(config2))
# Out:
# [StateSnapshot(values={'topic': 'pasta', 'joke': 'Why did the spaghetti go to therapy? \n\nBecause it was feeling a little "twisted".', 'explanation': 'The joke is a play on words. It starts with a setup question, "Why did the spaghetti go to therapy?" which implies that the spaghetti has a problem or is feeling unhappy. The punchline, "Because it was feeling a little \'twisted\'" has a double meaning.\n\nIn a literal sense, spaghetti is a type of food that is long and twisted in shape. So, the punchline is making a joke about the physical appearance of spaghetti.\n\nHowever, the phrase "feeling a little twisted" is also an idiom that means feeling anxious, confused, or disturbed. In this sense, the punchline is making a joke about the emotional state of the spaghetti.\n\nThe humor comes from the wordplay between the literal meaning of "twisted" (referring to the spaghetti\'s shape) and the idiomatic meaning (referring to the emotional state of the spaghetti). The joke is a clever and lighthearted way to make a pun on the word "twisted" and create a humorous connection between the setup and the punchline.'}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0bbcad-2048-637d-800a-235ac3512b20'}}, metadata={'source': 'loop', 'step': 10, 'parents': {}}, created_at='2025-11-07T11:13:42.978432+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0bbcad-1c6d-6f97-8009-1d81aacee34a'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'pasta', 'joke': 'Why did the spaghetti go to therapy? \n\nBecause it was feeling a little "twisted".', 'explanation': 'This joke is a play on words, a type of humor known as a pun. A pun is a joke that uses a word or phrase that has multiple meanings, or sounds similar to another word or phrase, to create a humorous effect.\n\nIn this joke, the word "crusty" has a double meaning. A crust is the outer layer of a pizza, but it can also describe someone or something that is feeling a bit rough, irritable, or ill. The joke is making a connection between the idea that a pizza has a crust, and the phrase "feeling a little crusty," which is a common expression meaning feeling a bit off or unwell.\n\nThe punchline of the joke is that the pizza goes to the doctor because it\'s feeling "a little crusty," which is a clever play on words that creates a humorous connection between the setup of the joke and the punchline.'}, next=('generate_explanation',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0bbcad-1c6d-6f97-8009-1d81aacee34a'}}, metadata={'source': 'loop', 'step': 9, 'parents': {}}, created_at='2025-11-07T11:13:42.574438+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0bbcad-1afd-67ee-8008-f1566554c394'}}, tasks=(PregelTask(id='16157228-c4ab-2913-d90a-98674df71ca6', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'The joke is a play on words. It starts with a setup question, "Why did the spaghetti go to therapy?" which implies that the spaghetti has a problem or is feeling unhappy. The punchline, "Because it was feeling a little \'twisted\'" has a double meaning.\n\nIn a literal sense, spaghetti is a type of food that is long and twisted in shape. So, the punchline is making a joke about the physical appearance of spaghetti.\n\nHowever, the phrase "feeling a little twisted" is also an idiom that means feeling anxious, confused, or disturbed. In this sense, the punchline is making a joke about the emotional state of the spaghetti.\n\nThe humor comes from the wordplay between the literal meaning of "twisted" (referring to the spaghetti\'s shape) and the idiomatic meaning (referring to the emotional state of the spaghetti). The joke is a clever and lighthearted way to make a pun on the word "twisted" and create a humorous connection between the setup and the punchline.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pasta', 'joke': 'Why did the pizza go to the doctor? \n\nBecause it was feeling a little crusty.', 'explanation': 'This joke is a play on words, a type of humor known as a pun. A pun is a joke that uses a word or phrase that has multiple meanings, or sounds similar to another word or phrase, to create a humorous effect.\n\nIn this joke, the word "crusty" has a double meaning. A crust is the outer layer of a pizza, but it can also describe someone or something that is feeling a bit rough, irritable, or ill. The joke is making a connection between the idea that a pizza has a crust, and the phrase "feeling a little crusty," which is a common expression meaning feeling a bit off or unwell.\n\nThe punchline of the joke is that the pizza goes to the doctor because it\'s feeling "a little crusty," which is a clever play on words that creates a humorous connection between the setup of the joke and the punchline.'}, next=('generate_joke',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0bbcad-1afd-67ee-8008-f1566554c394'}}, metadata={'source': 'loop', 'step': 8, 'parents': {}}, created_at='2025-11-07T11:13:42.423531+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0bbcad-1afa-68e9-8007-90d1069d1cc6'}}, tasks=(PregelTask(id='baf25d11-142e-db08-d467-da1991bc58ff', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why did the spaghetti go to therapy? \n\nBecause it was feeling a little "twisted".'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza go to the doctor? \n\nBecause it was feeling a little crusty.', 'explanation': 'This joke is a play on words, a type of humor known as a pun. A pun is a joke that uses a word or phrase that has multiple meanings, or sounds similar to another word or phrase, to create a humorous effect.\n\nIn this joke, the word "crusty" has a double meaning. A crust is the outer layer of a pizza, but it can also describe someone or something that is feeling a bit rough, irritable, or ill. The joke is making a connection between the idea that a pizza has a crust, and the phrase "feeling a little crusty," which is a common expression meaning feeling a bit off or unwell.\n\nThe punchline of the joke is that the pizza goes to the doctor because it\'s feeling "a little crusty," which is a clever play on words that creates a humorous connection between the setup of the joke and the punchline.'}, next=('__start__',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0bbcad-1afa-68e9-8007-90d1069d1cc6'}}, metadata={'source': 'input', 'step': 7, 'parents': {}}, created_at='2025-11-07T11:13:42.422327+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0bbcac-b0fa-61f1-8006-d5596e90f700'}}, tasks=(PregelTask(id='81437efe-84ae-9ab0-236b-d147ce9c8df7', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'pasta'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza go to the doctor? \n\nBecause it was feeling a little crusty.', 'explanation': 'This joke is a play on words, a type of humor known as a pun. A pun is a joke that uses a word or phrase that has multiple meanings, or sounds similar to another word or phrase, to create a humorous effect.\n\nIn this joke, the word "crusty" has a double meaning. A crust is the outer layer of a pizza, but it can also describe someone or something that is feeling a bit rough, irritable, or ill. The joke is making a connection between the idea that a pizza has a crust, and the phrase "feeling a little crusty," which is a common expression meaning feeling a bit off or unwell.\n\nThe punchline of the joke is that the pizza goes to the doctor because it\'s feeling "a little crusty," which is a clever play on words that creates a humorous connection between the setup of the joke and the punchline.'}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0bbcac-b0fa-61f1-8006-d5596e90f700'}}, metadata={'source': 'loop', 'step': 6, 'parents': {}}, created_at='2025-11-07T11:13:31.307240+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0bbcac-adb5-6b1f-8005-11377a1a0f09'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza go to the doctor? \n\nBecause it was feeling a little crusty.', 'explanation': 'This joke is a play on words, using puns and double meanings to create a humorous effect. Here\'s a breakdown of the joke:\n\n1. **"Feeling a little \'drained\'"**: The word "drained" has a double meaning here. In a literal sense, spaghetti is typically drained of excess water after being cooked. However, in a figurative sense, "feeling drained" is a common idiomatic expression meaning feeling exhausted or overwhelmed.\n\n2. **"Get to the \'root\' of its problems"**: The phrase "get to the root of the problem" is a common idiom that means to identify and address the underlying cause of a problem. In this joke, the word "root" is also a clever reference to the fact that spaghetti grows from roots, as it is a type of plant-based food.\n\nThe joke relies on the wordplay between these two meanings of "drained" and "root" to create a pun that connects the idea of spaghetti being cooked (drained of water) to the idea of seeking help for emotional problems (getting to the root of the issue). The humor comes from the unexpected twist on the expected meaning of the words.'}, next=('generate_explanation',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0bbcac-adb5-6b1f-8005-11377a1a0f09'}}, metadata={'source': 'loop', 'step': 5, 'parents': {}}, created_at='2025-11-07T11:13:30.964631+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0bbcac-ac27-6e0f-8004-bba9278702fe'}}, tasks=(PregelTask(id='dfe46e21-e629-1c8b-3399-f2804510a39b', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'This joke is a play on words, a type of humor known as a pun. A pun is a joke that uses a word or phrase that has multiple meanings, or sounds similar to another word or phrase, to create a humorous effect.\n\nIn this joke, the word "crusty" has a double meaning. A crust is the outer layer of a pizza, but it can also describe someone or something that is feeling a bit rough, irritable, or ill. The joke is making a connection between the idea that a pizza has a crust, and the phrase "feeling a little crusty," which is a common expression meaning feeling a bit off or unwell.\n\nThe punchline of the joke is that the pizza goes to the doctor because it\'s feeling "a little crusty," which is a clever play on words that creates a humorous connection between the setup of the joke and the punchline.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the spaghetti go to therapy? \n\nBecause it was feeling a little "drained" and wanted to get to the "root" of its problems.', 'explanation': 'This joke is a play on words, using puns and double meanings to create a humorous effect. Here\'s a breakdown of the joke:\n\n1. **"Feeling a little \'drained\'"**: The word "drained" has a double meaning here. In a literal sense, spaghetti is typically drained of excess water after being cooked. However, in a figurative sense, "feeling drained" is a common idiomatic expression meaning feeling exhausted or overwhelmed.\n\n2. **"Get to the \'root\' of its problems"**: The phrase "get to the root of the problem" is a common idiom that means to identify and address the underlying cause of a problem. In this joke, the word "root" is also a clever reference to the fact that spaghetti grows from roots, as it is a type of plant-based food.\n\nThe joke relies on the wordplay between these two meanings of "drained" and "root" to create a pun that connects the idea of spaghetti being cooked (drained of water) to the idea of seeking help for emotional problems (getting to the root of the issue). The humor comes from the unexpected twist on the expected meaning of the words.'}, next=('generate_joke',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0bbcac-ac27-6e0f-8004-bba9278702fe'}}, metadata={'source': 'loop', 'step': 4, 'parents': {}}, created_at='2025-11-07T11:13:30.801656+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0bbcac-ac16-6565-8003-f5cc9c8bd8e7'}}, tasks=(PregelTask(id='b56fa32f-2277-8ff0-cbf8-46606731b705', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why did the pizza go to the doctor? \n\nBecause it was feeling a little crusty.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pasta', 'joke': 'Why did the spaghetti go to therapy? \n\nBecause it was feeling a little "drained" and wanted to get to the "root" of its problems.', 'explanation': 'This joke is a play on words, using puns and double meanings to create a humorous effect. Here\'s a breakdown of the joke:\n\n1. **"Feeling a little \'drained\'"**: The word "drained" has a double meaning here. In a literal sense, spaghetti is typically drained of excess water after being cooked. However, in a figurative sense, "feeling drained" is a common idiomatic expression meaning feeling exhausted or overwhelmed.\n\n2. **"Get to the \'root\' of its problems"**: The phrase "get to the root of the problem" is a common idiom that means to identify and address the underlying cause of a problem. In this joke, the word "root" is also a clever reference to the fact that spaghetti grows from roots, as it is a type of plant-based food.\n\nThe joke relies on the wordplay between these two meanings of "drained" and "root" to create a pun that connects the idea of spaghetti being cooked (drained of water) to the idea of seeking help for emotional problems (getting to the root of the issue). The humor comes from the unexpected twist on the expected meaning of the words.'}, next=('__start__',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0bbcac-ac16-6565-8003-f5cc9c8bd8e7'}}, metadata={'source': 'input', 'step': 3, 'parents': {}}, created_at='2025-11-07T11:13:30.794511+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0bbca7-0651-64ad-8002-5ac0b8fd0c32'}}, tasks=(PregelTask(id='d6d7bebc-cf30-4766-9366-0b6f048d44ab', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'pizza'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pasta', 'joke': 'Why did the spaghetti go to therapy? \n\nBecause it was feeling a little "drained" and wanted to get to the "root" of its problems.', 'explanation': 'This joke is a play on words, using puns and double meanings to create a humorous effect. Here\'s a breakdown of the joke:\n\n1. **"Feeling a little \'drained\'"**: The word "drained" has a double meaning here. In a literal sense, spaghetti is typically drained of excess water after being cooked. However, in a figurative sense, "feeling drained" is a common idiomatic expression meaning feeling exhausted or overwhelmed.\n\n2. **"Get to the \'root\' of its problems"**: The phrase "get to the root of the problem" is a common idiom that means to identify and address the underlying cause of a problem. In this joke, the word "root" is also a clever reference to the fact that spaghetti grows from roots, as it is a type of plant-based food.\n\nThe joke relies on the wordplay between these two meanings of "drained" and "root" to create a pun that connects the idea of spaghetti being cooked (drained of water) to the idea of seeking help for emotional problems (getting to the root of the issue). The humor comes from the unexpected twist on the expected meaning of the words.'}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0bbca7-0651-64ad-8002-5ac0b8fd0c32'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2025-11-07T11:10:59.194553+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0bbca7-025a-603a-8001-e7efa0fab6b6'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'pasta', 'joke': 'Why did the spaghetti go to therapy? \n\nBecause it was feeling a little "drained" and wanted to get to the "root" of its problems.'}, next=('generate_explanation',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0bbca7-025a-603a-8001-e7efa0fab6b6'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2025-11-07T11:10:58.778719+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0bbca7-0084-631f-8000-ed30022e8f1b'}}, tasks=(PregelTask(id='4136dc10-08a8-1ef2-7281-377787fbea53', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'This joke is a play on words, using puns and double meanings to create a humorous effect. Here\'s a breakdown of the joke:\n\n1. **"Feeling a little \'drained\'"**: The word "drained" has a double meaning here. In a literal sense, spaghetti is typically drained of excess water after being cooked. However, in a figurative sense, "feeling drained" is a common idiomatic expression meaning feeling exhausted or overwhelmed.\n\n2. **"Get to the \'root\' of its problems"**: The phrase "get to the root of the problem" is a common idiom that means to identify and address the underlying cause of a problem. In this joke, the word "root" is also a clever reference to the fact that spaghetti grows from roots, as it is a type of plant-based food.\n\nThe joke relies on the wordplay between these two meanings of "drained" and "root" to create a pun that connects the idea of spaghetti being cooked (drained of water) to the idea of seeking help for emotional problems (getting to the root of the issue). The humor comes from the unexpected twist on the expected meaning of the words.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pasta'}, next=('generate_joke',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0bbca7-0084-631f-8000-ed30022e8f1b'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2025-11-07T11:10:58.586230+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0bbca7-0075-603f-bfff-479ba8e9609b'}}, tasks=(PregelTask(id='ef09b583-bcc6-1f5d-9a36-803f560c7503', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why did the spaghetti go to therapy? \n\nBecause it was feeling a little "drained" and wanted to get to the "root" of its problems.'}),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0bbca7-0075-603f-bfff-479ba8e9609b'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2025-11-07T11:10:58.580066+00:00', parent_config=None, tasks=(PregelTask(id='9024cd4a-bf71-87bb-0cfa-aa03bc9abd98', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'pasta'}),), interrupts=())]
